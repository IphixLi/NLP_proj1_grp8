# %%
import wikipedia
import time

class WikiSearch:
    def __init__(self) -> None:
        self.terms = ['actor', 'actress', 'director']
        self.logs = []
        self.cache = {}
        self.count = {
            "cache_hit": 0,
            "cache_miss": 0,
            "total_time": 0, # for cache_miss
            "exception_count": 0, # for exception
            "exception_time": 0 # exception total time
        }
    
    # def __del__(self):
    #     self.print_stats()
    
    def print_stats(self):
        print("---------------WikiSearch stats:---------------")
        for k, v in self.count.items():
            print(f"{k}: {v}")

    def check_validity(self, name, content):
        for n in name.lower().split():
            if content.lower().find(n) != -1:
                return True
        return False

    def most_frequent_term(self, content, terms) -> list:
        count_map = {term: content.lower().count(term) for term in terms}
        counts = sorted(count_map.items(), key=lambda x: x[1], reverse=True)
        max_count = counts[0][1]
        
        if max_count > 0:
            most_frequent = [term for term, count in counts if count == max_count]
        else:
            most_frequent = []
        return most_frequent

    def possible_job_list(self, name) -> list:
        try:
            start = time.time()
            if name in self.cache:
                self.count["cache_hit"] += 1
                self.count["total_time"] += time.time() - start
                return self.cache[name]

            search_results = wikipedia.search(name)
            print(search_results[:3])
            if not search_results:
                self.logs.append(f"- wikipedia: No search results found for '{name}'")
                self.cache[name] = []
                self.countexception_count += 1
                self.count["exception_time"] += time.time() - start
                return []
            
            content = ""
            for res in search_results[:3]:
                content = wikipedia.summary(res, sentences=5, auto_suggest=False)
                if self.check_validity(name, content):
                    break
            
            if not content:
                self.cache[name] = []
                self.count["cache_miss"] += 1
                self.count["total_time"] += time.time() - start
                return []
            res = self.most_frequent_term(content, self.terms)
            self.cache[name] = res
            self.count["cache_miss"] += 1
            self.count["total_time"] += time.time() - start
            return res
        except wikipedia.exceptions.DisambiguationError as e:
            self.logs.append(f"- wikipedia: Ambiguous. Possible matches include: {e.options} for '{name}'")
            self.count["exception_count"] += 1
            self.count["exception_time"] += time.time() - start
            return []
        except wikipedia.exceptions.PageError:
            self.logs.append(f"- wikipedia: The page does not exist: '{name}'")
            self.count["exception_count"] += 1
            self.count["exception_time"] += time.time() - start
            return []
        except Exception as e:
            self.logs.append(f"- wikipedia: {e}")
            self.count["exception_count"] += 1
            self.count["exception_time"] += time.time() - start
            return []
    
    def write_logs(self):
        if self.logs:
            with open("wiki_search_logs.txt", "w") as f:
                f.write("\n".join(self.logs))

# %%
names = ["Lee Ang", "ah Lee Ang", "Ang Lee", "Booo Ang Lee", "Lee Ang", "Ang Lee", "Boooooooo Ang Lee", "Boooooooo Ang Lee"]
wiki = WikiSearch()
for name in names:
    result = wiki.possible_job_list(name)
    print(f"'{name}' is likely an actor/actress or director: {result}")
wiki.print_stats()
# Out:
# ['Ang Lee', 'Hulk (film)', 'Michelle Ang']
# 'Lee Ang' is likely an actor/actress or director: ['director']
# ['Lee Ji-ah', 'Lee Chung-ah', 'Lee Ah-hyun']
# 'ah Lee Ang' is likely an actor/actress or director: ['actress']
# ['Ang Lee', 'Hulk (film)', 'Life of Pi (film)']
# 'Ang Lee' is likely an actor/actress or director: ['director']
# []
# 'Booo Ang Lee' is likely an actor/actress or director: []
# 'Lee Ang' is likely an actor/actress or director: ['director']
# 'Ang Lee' is likely an actor/actress or director: ['director']
# []
# 'Boooooooo Ang Lee' is likely an actor/actress or director: []
# 'Boooooooo Ang Lee' is likely an actor/actress or director: []
# ---------------WikiSearch stats:---------------
# cache_hit: 3
# cache_miss: 3
# total_time: 0.0001697540283203125
# exception_count: 2
# exception_time: 1.621246337890625e-05

# %%
print(type(wikipedia.page("Maggie Smith")))
# print(wikipedia.summary("Maggie Smith", sentences=2))
# Out:
# <class 'wikipedia.wikipedia.WikipediaPage'>

# %%
from imdb import Cinemagoer
import json

# create an instance of the Cinemagoer class
ia = Cinemagoer()

people = ia.search_person("Bryn Cranston")
first_person = people[0]
person = ia.get_person(first_person.personID)

print(person.get('name'))

def print_filmography(person):
    filmography = person.get('filmography', {})
    
    for category, movies in filmography.items():
        print(f"\n{category.upper()}:\n{'-' * 40}")
        for movie in movies:
            title = movie.get('title')
            year = movie.get('year')
            if title and year:
                print(f"{title} ({year})")
            elif title:
                print(title)

print_filmography(person)

# def is_actor_or_actress(person):
#     # Check the filmography
#     filmography = person.get('filmography', {})
    
#     print(json.dumps(filmography, indent=4))
    
#     # Check if they have roles in "actor" or "actress" categories
#     if 'actor' in filmography or 'actress' in filmography:
#         return True
#     return False

# result = is_actor_or_actress(person)
# print(f"{person['name']} is an actor/actress: {result}")
# Out:
# Bryan Cranston
#
# ACTOR:
# ----------------------------------------
# Everything's Going to Be Great
# Argylle (2024)
# Jackpot
# It's Always Sunny in Philadelphia (2023)
# Asteroid City (2023)
# Your Honor (2020)
# PopCorners: Breaking Bad Super Bowl Commercial - Extended Version (2023)
# Better Call Saul (2022)
# Experience Yosemite (2022)
# Jerry and Marge Go Large (2022)
# The Stand (2020)
# The One and Only Ivan (2020)
# Home Movie: The Princess Bride (2020)
# Family Guy (2006)
# Mountain Dew Zero Sugar: As Good as the Original (2020)
# El Camino: A Breaking Bad Movie (2019)
# SuperMansion (2015)
# Last Week Tonight with John Oliver (2019)
# Robot Chicken (2011)
# Isle of Dogs (2018)
# Electric Dreams (2017)
# Curb Your Enthusiasm (2017)
# Last Flag Flying (2017)
# The Disaster Artist (2017)
# The Upside (2017)
# Power Rangers (2017)
# Sneaky Pete (2015)
# Why Him? (2016)
# Saturday Night Live (2016)
# In Dubious Battle (2016)
# Wakefield (2016)
# The Infiltrator (2016)
# All the Way (2016)
# Get a Job (2016)
# Zendaya: Neverland (2016)
# Kung Fu Panda 3 (2016)
# Trumbo (2015)
# Esurance: Sorta Pharmacy (2015)
# Godzilla (2014)
# Family Guy: The Quest for Stuff (2014)
# Writer's Block
# How I Met Your Mother (2006)
# Breaking Bad (2008)
# Cold Comes the Night (2013)
# Übermansion (2013)
# The Cleveland Show (2012)
# The Simpsons (2012)
# Seth Rogen = Worst Person in the World (2013)
# 30 Rock (2012)
# Argo (2012)
# Surviving Hawking (2012)
# Total Recall
# Rock of Ages (2012)
# Madagascar 3: Europe's Most Wanted (2012)
# Archer (2012)
# John Carter (2012)
# Madagascar 3: The Video Game (2012)
# Red Tails (2012)
# Batman: Year One (2011)
# Contagion (2011)
# Glenn Martin DDS (2010)
# Larry Crowne (2011)
# Leave (2011)
# Drive
# Detachment (2011)
# The Lincoln Lawyer (2011)
# The Handlers (2011)
# Love Ranch (2010)
# American Dad! (2005)
# Breaking Bad: Original Minisodes (2009)
# The Hollywood Quad (2008)
# Hard Four (2007)
# Fallen (2007)
# Lilo & Stitch: The Series (2003)
# Malcolm in the Middle (2000)
# Dark Mind (2006)
# Little Miss Sunshine (2006)
# Magnificent Desolation: Walking on the Moon (2005)
# Illusion (2004)
# Seeing Other People (2004)
# Thanksgiving Family Reunion (2003)
# The Santa Claus Brothers (2001)
# 'Twas the Night (2001)
# The King of Queens (1999)
# Gary & Mike (2001)
# Clerks (2000)
# The Big Thing (2000)
# Terror Tract (2000)
# The Pretender (1999)
# 3rd Rock from the Sun (1999)
# Last Chance (1999)
# Honey, I Shrunk the Kids: The TV Show (1998)
# Working (1998)
# Chicago Hope (1998)
# The X-Files (1998)
# Diagnosis Murder (1996)
# V.I.P. (1998)
# Saving Private Ryan (1998)
# From the Earth to the Moon (1998)
# Brooklyn South (1998)
# Eagle Riders (1996)
# Total Security (1997)
# Seinfeld (1994)
# Time Under Fire (1997)
# Alright Already (1997)
# Pearl (1997)
# Sabrina the Teenage Witch (1997)
# Goode Behavior (1997)
# Dogs (1997)
# Babylon 5 (1997)
# Moloney (1997)
# Strategic Command (1997)
# Street Corner Justice (1996)
# The Rockford Files: Punishment and Crime (1996)
# Armitage III: Poly-Matrix (1996)
# That Thing You Do! (1996)
# The Louie Show (1996)
# Murder, She Wrote (1986)
# Armitage III (1995)
# Extreme Blue (1995)
# Teknoman (1995)
# Nowhere Man (1995)
# Land's End (1995)
# Brotherly Love (1995)
# Kissing Miranda (1995)
# Touched by an Angel (1995)
# Days Like This (1994)
# Macross Plus (1994)
# Men Who Hate Women & the Women Who Love Them (1994)
# The Companion (1994)
# Street Fighter II: The Animated Movie (1994)
# Clean Slate (1994)
# Walker, Texas Ranger (1994)
# Viper (1994)
# Erotique (1994)
# The Super Dimension Century Orguss 02 (1993)
# Mighty Morphin Power Rangers (1993)
# Prophet of Evil: The Ervil LeBaron Story (1993)
# The Disappearance of Nora (1993)
# Moldiver (1993)
# Davis Rules (1992)
# L.A. Law (1992)
# Matlock (1987)
# Dead Silence (1991)
# The Flash (1991)
# Dead Space (1991)
# Hull High (1990)
# Corporate Affairs (1990)
# Jake and the Fatman (1990)
# Capital News (1990)
# Baywatch (1989)
# I Know My First Name Is Steven (1989)
# Falcon Crest (1989)
# Raising Miranda (1988)
# The Big Turnaround (1988)
# Amazon Women on the Moon (1987)
# The Return of the Six-Million-Dollar Man and the Bionic Woman (1987)
# Hill Street Blues (1987)
# Wings of Honneamise (1987)
# North & South: Book 2, Love & War (1986)
# Airwolf (1986)
# Cover Up (1985)
# Loving (1983)
# CHiPs (1982)
# Crisis Counselor (1982)
# Call of the Wild: Howl, Buck (1981)
# Galaxy Express 999: Can You Love Like a Mother!? (1980)
# To Race the Wind (1980)
#
# PRODUCER:
# ----------------------------------------
# Your Honor (2020)
# Sneaky Pete (2015)
# SuperMansion (2015)
# The Dangerous Book for Boys (2018)
# Electric Dreams (2017)
# The Infiltrator (2016)
# All the Way (2016)
# Breaking Bad (2011)
# The Handlers (2011)
# KidSmartz (2003)
# Last Chance (1999)
#
# WRITER:
# ----------------------------------------
# Sneaky Pete
# The Dangerous Book for Boys
# The Handlers (2011)
# Last Chance (1999)
#
# DIRECTOR:
# ----------------------------------------
# Your Honor (2021)
# Sneaky Pete (2017)
# Modern Family (2012)
# Breaking Bad (2009)
# The Office (2012)
# Special Unit (2006)
# Big Day (2006)
# Malcolm in the Middle (2003)
# Last Chance (1999)
#
# SOUNDTRACK:
# ----------------------------------------
# The Tonight Show Starring Jimmy Fallon (2016)
# Breaking Bad (2010)
# Saturday Night Live (2010)
# Malcolm in the Middle (2001)
# 'Twas the Night (2001)
# 3rd Rock from the Sun (1999)
#
# THANKS:
# ----------------------------------------
# All Together Now (2020)
# Let's Scare Julie (2019)
# The Meddler (2015)
# The Taking of Deborah Logan (2014)
# Breaking Bad Season 3: Silent But Deadly - The Brothers Moncada (2011)
# John Delaney Died Last Night (2011)
# Little Devil (2009)
#
# SELF:
# ----------------------------------------
# The Give Back-ular Spectacular
# Entertainment Tonight (2008)
# Watch What Happens Live with Andy Cohen (2023)
# Watch What Happens Live with Andy Cohen (2023)
# Live with Kelly and Mark (2011)
# Today (2012)
# Access Hollywood (2023)
# Eating Out with Eric & Steve (2023)
# The Late Late Show with James Corden (2015)
# Late Night with Seth Meyers (2016)
# CBS Mornings (2022)
# The Tonight Show Starring Jimmy Fallon (2014)
# Who's Talking to Chris Wallace (2023)
# Hot Ones (2016)
# Club Random with Bill Maher (2023)
# Jimmy Kimmel Live! (2003)
# The Kelly Clarkson Show (2023)
# Conan O'Brien Needs a Friend (2021)
# Armchair Expert with Dax Shepard (2022)
# The Talk (2022)
# The View (2014)
# The Late Show with Stephen Colbert (2015)
# The 75th Annual Tony Awards (2022)
# The Broadway Show with Tamsen Fadal (2022)
# Celebrity Page (2017)
# Sell/Buy/Date (2022)
# Celebrating Betty White: America's Golden Girl (2022)
# An Audience with Adele (2021)
# Animal (2021)
# Superstar (2021)
# Hollywood Insider (2021)
# Hart to Heart (2021)
# Show of titles (2021)
# The 43rd Annual Kennedy Center Honors (2021)
# The Oscars (2021)
# Palm Springs Air Museum's 25th Silver anniversary (2021)
# The Graham Norton Show (2016)
# 2021 Golden Globe Awards (2021)
# Conan (2011)
# Fox News Sunday (2021)
# The Project (2021)
# SmartLess (2021)
# Sunday Today with Willie Geist (2020)
# The Daily Show (2010)
# That Scene with Dan Patrick (2020)
# The Ellen DeGeneres Show (2015)
# CBS This Morning (2016)
# Variety's Salute to Service (2020)
# Stephen Colbert's Election Night 2020: Democracy's Last Stand: Building Back America Great Again Better 2020 (2020)
# 2020 Samuel J. Heyman Service to America Medals (2020)
# Extra (2014)
# Dish Nation (2019)
# Entertainment Tonight Canada (2020)
# Good Morning America (2012)
# Ford: The Bronco 4-Door with Kip Moore (2020)
# National Memorial Day Concert (2020)
# The Red Nose Day Special (2020)
# The Story of Soaps (2020)
# Covid Is No Joke (2020)
# Heroes Manufactured: Creators Unleashed (2020)
# David Blaine: The Magic Way (2020)
# Ancient Caves (2020)
# Jeopardy! (2020)
# Jeopardy! The Greatest of All Time (2020)
# The Big Interview with Dan Rather (2019)
# The 71st Primetime Emmy Awards (2019)
# Broadway Profiles with Tamsen Fadal (2019)
# The 73rd Annual Tony Awards (2019)
# Show People with Paul Wontorek (2019)
# CBS News Sunday Morning (2013)
# The Dan Patrick Show (2019)
# The 12th Annual CNN Heroes: An All-Star Tribute (2018)
# 21st Annual Mark Twain Prize for American Humor celebrating: Julia Louis-Dreyfus (2018)
# Pink Elephants (2018)
# Brief But Spectacular (2018)
# The 2018 Primetime Creative Arts Emmy Awards (2018)
# Aaron Paul Discovers Bryan Cranston Living in Breaking Bad RV (2018)
# Every Act of Life (2018)
# WGN Morning News (2016)
# Isle of Dogs: Ode to Dogs on Set (2018)
# Close Up with the Hollywood Reporter (2018)
# The EE British Academy Film Awards (2018)
# The One Show (2018)
# Better Call Saul: It's a Bad, Bad World (2018)
# Talking with Chris Hardwick (2017)
# The Disaster Artist: Oh, Hi Mark: Making a Disaster (2017)
# Good Morning Britain (2017)
# Hand in Hand: A Benefit for Hurricane Relief (2017)
# Kevin Pollak's Chat Show (2010)
# The Words That Built America (2017)
# The Red Nose Day Special (2017)
# Made in Hollywood (2012)
# Talking Saul (2017)
# Watching, Waiting (2017)
# The Insider (2014)
# E! Live from the Red Carpet (2008)
# The 23rd Annual Screen Actors Guild Awards (2017)
# The 74th Annual Golden Globe Awards 2017 (2017)
# The Big Fat Quiz of the Year (2016)
# Special Look (2016)
# Weekend Today (2016)
# 24 Hours of Reality: The Road Forward (2016)
# The 2nd Annual Carney Awards (2016)
# The Chris Moyles Show on Radio X (2016)
# KRQE News 13 (2016)
# The Infiltrator: The Three Bobs (2016)
# 60 Minutes (2016)
# The 68th Primetime Emmy Awards (2016)
# Bryan Cranston: Becoming LBJ (2016)
# Larry King Now (2016)
# PoliticKING with Larry King (2016)
# Overheard (2016)
# Real Time with Bill Maher (2011)
# Birthday Stories with Lynn Hirschberg (2016)
# The Oscars (2016)
# 20/20 (2016)
# IMDb First Credit (2016)
# The EE British Academy Film Awards (2016)
# Film '72 (2016)
# LA Times: The Envelope (2016)
# 22nd Annual Screen Actors Guild Awards (2016)
# World Premiere (2016)
# 21st Annual Critics' Choice Awards (2016)
# Critics' Choice Awards Red Carpet Live
# 73rd Golden Globe Awards (2016)
# Tavis Smiley (2009)
# Variety Studio: Actors on Actors (2015)
# Inside the Actors Studio (2015)
# PBS NewsHour (2015)
# The British Academy Britannia Awards (2015)
# Who Do You Think You Are? (2015)
# Live from the Red Carpet: The 2015 Tony Awards (2015)
# The 69th Annual Tony Awards (2015)
# Inside Comedy (2015)
# The 21st Annual Screen Actors Guild Awards (2015)
# 72nd Golden Globe Awards (2015)
# The Colbert Report (2013)
# The Concert for Valor (2014)
# Fox and Friends (2014)
# Godzilla: Force of Nature (2014)
# Godzilla: Rebirth of an Icon (2014)
# Inside Edition (2014)
# The 66th Primetime Emmy Awards (2014)
# Howard Stern Birthday Bash (2014)
# The 68th Annual Tony Awards (2014)
# Janela Indiscreta (2014)
# Weekend Ticket (2014)
# Single Stories (2014)
# Bryan Cranston Helps Ask Girl to Prom (2014)
# Charlie Rose (2013)
# Late Show with David Letterman (2010)
# The Broadway.com Show (2014)
# WEDU Arts Plus (2014)
# 20th Annual Screen Actors Guild Awards (2014)
# Fatherhood (2014)
# 71st Golden Globe Awards (2014)
# Big History (2013)
# A Discussion with the Cast of Argo (2013)
# No Half Measures: Creating the Final Season of Breaking Bad (2013)
# David Blaine: Real or Magic (2013)
# Talking Bad (2013)
# The 65th Primetime Emmy Awards (2013)
# Late Night with Jimmy Fallon (2010)
# The Tonight Show with Jay Leno (2008)
# The Writers' Room (2013)
# Comic-Con All Access 2013 (2013)
# Argo: Inside Story (2013)
# The 2013 Film Independent Spirit Awards (2013)
# 19th Annual Screen Actors Guild Awards (2013)
# Revealed (2013)
# 70th Golden Globe Awards (2013)
# The After After Party with Steven Michael Quezada (2011)
# The Hollywood Fast Lane (2012)
# Vivir de cine (2012)
# The Late Late Show with Craig Ferguson (2005)
# Anderson Live (2012)
# Chelsea Lately (2012)
# Up Close with Carrie Keagan (2012)
# Reel Junkie (2012)
# The 64th Primetime Emmy Awards (2012)
# Alien Deep with Bob Ballard (2012)
# 2012 Do Something Awards (2012)
# Comic Con 2012 Live (2012)
# Chris Hardwick's All-Star Celebrity Bowling (2012)
# CinemAbility: The Art of Inclusion (2012)
# The 2012 Film Independent Spirit Awards (2012)
# 2012 Writers Guild Awards (2012)
# Shit Emmy Award Winning Actors Say (2012)
# 18th Annual Screen Actors Guild Awards (2012)
# The 69th Annual Golden Globe Awards (2012)
# The Contagion Detectives (2012)
# The Reality of Contagion (2012)
# America in Primetime (2011)
# WTF with Marc Maron (2011)
# The Hour (2011)
# The 63rd Primetime Emmy Awards (2011)
# The Rich Eisen Podcast (2011)
# White Heat: Cranston on Fire (2011)
# Pizza of Destiny: Cranston's Greatest Shot (2011)
# 17th Annual Screen Actors Guild Awards (2011)
# The 3 Minute Talk Show (2011)
# The 68th Annual Golden Globe Awards (2011)
# Night of Too Many Stars: An Overbooked Concert for Autism Education (2010)
# Saturday Night Live (2010)
# The 62nd Primetime Emmy Awards (2010)
# Celebrity Liar (2010)
# In the House with Peter Bart & Peter Guber (2010)
# Getting There Is the Hard Part (2010)
# Lopez Tonight (2010)
# Last Call with Carson Daly (2010)
# The 14th Annual Satellite Awards (2009)
# The 61st Primetime Emmy Awards (2009)
# Buzz: at&T Original Documentaries (2009)
# Séries express (2009)
# The Bonnie Hunt Show (2009)
# The Soup (2009)
# The 2009 Independent Spirit Awards (2009)
# The 60th Primetime Emmy Awards (2008)
# 2008 Primetime Creative Arts Emmy Awards (2008)
# Dog Tales (2008)
# Rachael Ray (2008)
# 2008 Film Independent's Spirit Awards (2008)
# Talkshow with Spike Feresten (2008)
# Man of a Thousand Faces (2008)
# Shootout (2008)
# Seinfeld: Inside Look (2005)
# Making of 'Breaking Bad' (2007)
# TV Land Confidential (2007)
# Jerry Seinfeld, Submarine Captain (2007)
# Thank God You're Here (2007)
# The 58th Annual Primetime Emmy Awards (2006)
# My First Time (2006)
# Celebrity Poker Showdown (2005)
# The Tony Danza Show (2004)
# Running with the Egg: Making a 'Seinfeld' (2005)
# Weekends at the DL (2005)
# SoapTalk (2004)
# Reflections on 'the X-Files' (2004)
# The 100 Most Memorable TV Moments (2004)
# The Bench: Life Before 'Seinfeld' (2004)
# ALF's Hit Talk Show (2004)
# The Late Late Show with Craig Kilborn (2004)
# KidSmartz (2003)
# The Bronx Bunny Show (2003)
# The Wayne Brady Show (2003)
# The 55th Annual Primetime Emmy Awards (2003)
# Good Day Live (2003)
# Open Mike with Mike Bullard (2003)
# The 60th Annual Golden Globe Awards (2003)
# Mad TV (2002)
# The 4th Annual Family Television Awards (2002)
# Hollywood Squares (2000)
# Disney Channel: Express Yourself - 9/11 Patriotism Second Commercial (2001)
# Express Yourself (2001)
# 70th Annual Hollywood Christmas Parade (2001)
# Total Access 24/7 (2001)
# HBO First Look (1998)
# The Dating Game (1979)
#
# ARCHIVE FOOTAGE:
# ----------------------------------------
# Disparu (2023)
# KCAL 9 News (2023)
# Tyrone Magnus (2023)
# Nerdrotic (2023)
# FOX 11 News LA (2023)
# Josiah Rises (2023)
# Entertainment Tonight (2014)
# The Comments Section with Brett Cooper (2023)
# DDayCobra (2023)
# Redbar (2023)
# Nostalgia Critic (2022)
# History of the Sitcom (2021)
# Fox News Sunday (2021)
# Let Me Explain (2021)
# The Michael Knowles Show (2021)
# Canswers (2020)
# The Hollywood Moment at Home Edition (2020)
# Celebrity Page (2017)
# The Graham Norton Show (2017)
# 60 Minutes (2017)
# The Insider (2016)
# The Late Show with Stephen Colbert (2016)
# All the Way: A Walk Through History (2016)
# Live with Kelly and Mark (2016)
# Nudes in the News (2016)
# Extra (2014)
# Caddicarus (2016)
# Last Week Tonight with John Oliver (2015)
# Malcolm: rencontre avec l'équipe (2014)
# Inside Edition (2014)
# TV's Nastiest Villains (2014)
# Argo: Tony Mendez on Tony Mendez (2013)
# Jesse! The Breaking Bad Spin-Off (2013)
# MythBusters (2013)
# Rescued from Tehran: We Were There (2012)
# WTF with Marc Maron (2012)
# Seinfeld: Inside Look (2005)

# %%
from imdb import Cinemagoer
import json

# create an instance of the Cinemagoer class
ia = Cinemagoer()

def print_movie_info(movie_name):
    # Search for the movie
    movies = ia.search_movie(movie_name)
    if not movies:
        print(f"No movie found with the name '{movie_name}'.")
        return

    # Get detailed information about the first matching movie
    movie = ia.get_movie(movies[0].movieID)
    
    # Print details
    title = movie.get('title')
    year = movie.get('year')
    directors = ", ".join([person['name'] for person in movie.get('directors', [])])
    cast = ", ".join([person['name'] for person in movie.get('cast', [])])  # Top 5 actors
    plot = movie.get('plot outline')
    rating = movie.get('rating')
    genres = ", ".join(movie.get('genres', []))
    
    print(f"Title: {title}")
    print(f"Year: {year}")
    print(f"Directors: {directors}")
    print(f"Top Cast: {cast}")
    print(f"Plot Outline: {plot}")
    print(f"Rating: {rating}")
    print(f"Genres: {genres}")

# Example usage
movie_name = "Hatfields McCoys"
print_movie_info(movie_name)
# Out:
# Title: Hatfields & McCoys
# Year: 2012
# Directors:
# Top Cast: Kevin Costner, Bill Paxton, Matt Barr, Tom Berenger, Powers Boothe, Andrew Howard, Jena Malone, Sarah Parish, Lindsay Pulsipher, Ronan Vibert, Joe Absolom, Noel Fisher, Boyd Holbrook, Tom McKay, Sam Reid, Mare Winningham, Greg Patmore, Max Deacon, John Bell, Nick Dunning, Katie Griffiths, Joy McBrinn, Adam Jones, Darrell Fetty, Jon Bloch, Bill Millsap, Michael Woods, Park Chisolm, Stacha Hicks, Levi Bowling, Jilon VanOver, Damian O'Hare, Andy Gathergood, Christopher Hatherall, Noah Taylor, Ben Cartwright, Jack Laskey, Jonathan Fredrick, Michael Jibson, Chad Hugghins, Tyler Jackson, Alixandra Fuchs, Lloyd Hutchinson, Michael Greco, Rebecca Calder, Serbanescu Florin, Constantin Viscreanu, Ionut Alexandru, James Carroll Jordan, Rob Moran
# Plot Outline: The story of the feud that nearly launched a war between Kentucky and West Virginia. Devil Anse Hatfield and Randall McCoy were close friends until near the end of the Civil War, when they return to their homes -- Hatfield in West Virginia and McCoy in Kentucky -- to increasing tensions and misunderstandings that quickly lead to all-out warfare between the clans (partially caused by a stolen pig). As hostilities grow and outside forces become involved in the fight, the states where the families live are brought to the brink of another war as the feud makes international headlines, the states' governors clash and the U.S. Supreme Court eventually intervenes.
# Rating: 7.9
# Genres: Drama, History, Romance, War, Western
